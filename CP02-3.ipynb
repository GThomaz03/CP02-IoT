# %%
# !pip install ultralytics -q

# %%
from ultralytics import YOLO

# %%
# !yolo download model=yolov8n.pt source=coco128
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 911, in entrypoint
#     check_dict_alignment(full_args_dict, {a: ""})
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 502, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'download' is not a valid YOLO argument.
#
#     Arguments received: ['yolo', 'download', 'model=yolov8n.pt', 'source=coco128']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['segment', 'pose', 'detect', 'obb', 'classify']
#                 MODE (required) is one of ['train', 'benchmark', 'track', 'val', 'predict', 'export']
# ...

# %%
model = YOLO("yolov8n.pt")
model.train(data="coco128.yaml", epochs=3, imgsz=640)
# Out:
# Ultralytics 8.3.213 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from IPython.display import Image, display
display(Image(filename='/content/runs/detect/train/results.png'))

# %%
from ultralytics import YOLO
from IPython.display import Image, display

model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model.predict("onibus.jpg", save=True)

display(Image(filename='runs/detect/predict/onibus.jpg'))
# Out:
# image 1/1 /content/onibus.jpg: 480x640 1 person, 1 car, 1 bus, 201.6ms
# Speed: 4.8ms preprocess, 201.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict3
